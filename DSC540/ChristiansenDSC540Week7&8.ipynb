# %% [markdown]
# ### DSC Week 7 & 8
# ### Madison Christiansen

# %%
import pandas as pd
import numpy as np
candydf = pandas.read_excel('/Users/madisonchristiansen/Desktop/candyhierarchy2017.xlsx')
candydf
# Out:
# /Users/madisonchristiansen/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# ...

# %%
## Remove duplicates
candydf = candydf.drop_duplicates(subset='Internal ID', keep="first")
candydf
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# ...

# %%
## Filter out missing data - the column that has a lot of missing data 
candydf.isnull().sum().sort_values(ascending=False)
candydf = candydf.drop('Unnamed: 113', axis=1)

# %%
## Create hierarchical index
col = candydf.columns
df_ind = candydf.set_index(['Internal ID', 'Q4: COUNTRY', 'Q5: STATE, PROVINCE, COUNTY, ETC'])
df_ind.sort_index()
# Out:
#                                                          Q1: GOING OUT?  \
# Internal ID Q4: COUNTRY Q5: STATE, PROVINCE, COUNTY, ETC
# 90258773    NaN         NaN                                         NaN
# 90272821    USA         NM                                           No
# 90272829    USA         Virginia                                    NaN
# 90272840    us          or                                           No
# 90272841    usa         exton pa                                     No
# ...                                                                 ...
# 90314359    USA         MD                                           No
# 90314580    USA         New York                                     No
# 90314634    USA         Tennessee                                    No
# 90314658    Usa         North Carolina                               No
# 90314802    usa         Pennsylvania                                 No
#
# ...

# %%
## pivot
pivotdf = candydf.pivot(index='Internal ID', columns='Q6 | Any full-sized candy bar', values='Q9: OTHER COMMENTS')
pivotdf.head()
# Out:
# Q6 | Any full-sized candy bar  NaN DESPAIR  \
# Internal ID
# 90258773                       NaN     NaN
# 90272821                       NaN     NaN
# 90272829                       NaN     NaN
# 90272840                       NaN     NaN
# 90272841                       NaN     NaN
#
# Q6 | Any full-sized candy bar                                                JOY  \
# Internal ID
# 90258773                                                                     NaN
# 90272821                       Bottom line is Twix is really the only candy w...
# 90272829                                                                     NaN
# 90272840                                                  Raisins can go to hell
# 90272841                                                                     NaN
#
# Q6 | Any full-sized candy bar  MEH
# Internal ID
# 90258773                       NaN
# 90272821                       NaN
# 90272829                       NaN
# ...

# %%
## Split/Apply/Combine
## Grouping with Functions
myseries = pd.Series(
 data=['THREE', 'ONE', 'TWO'],
 index=['A', 'B', 'C']
)
def GROUP(grp):
 return myseries

grouped = candydf.groupby(['Q4: COUNTRY', 'Internal ID']).apply(func=GROUP)

grouped
# Out:
#                              A    B    C
# Q4: COUNTRY Internal ID
# 1           90288589     THREE  ONE  TWO
# 32          90276056     THREE  ONE  TWO
# 35          90273290     THREE  ONE  TWO
# 45          90275804     THREE  ONE  TWO
# 46          90274626     THREE  ONE  TWO
# ...                        ...  ...  ...
# usa         90311726     THREE  ONE  TWO
#             90312849     THREE  ONE  TWO
#             90313367     THREE  ONE  TWO
#             90314802     THREE  ONE  TWO
# usas        90275719     THREE  ONE  TWO
#
# [2396 rows x 3 columns]

# %%
df2 = pandas.read_excel('/Users/madisonchristiansen/Desktop/BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx')
df2
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
## Convert between string and date time
df2['New Timestamp'] = pd.to_datetime(df2['Timestamp'], format='%m%d%Y%H%M%S')
df2
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
## Convert timestamps to periods and back - new period column
df2['Period'] = pd.DatetimeIndex(df2['Timestamp']).to_period('M')
df2
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...
