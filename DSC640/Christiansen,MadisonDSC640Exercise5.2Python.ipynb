# %% [markdown]
# ## DSC 640 Exercise 5.2 - Python
# ## Madison Christiansen

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go

df = pd.read_csv('/Users/madisonchristiansen/Desktop/birth-rate.csv')   
df.tail()
# Out:
#           Country    1960    1961    1962    1963    1964    1965    1966  \
# 229         Samoa  48.202  47.788  47.226  46.491  45.591  44.558  43.447
# 230   Yemen, Rep.  54.501  54.516  54.563  54.645  54.761  54.914  55.100
# 231  South Africa  42.267  41.993  41.610  41.112  40.520  39.883  39.268
# 232        Zambia  48.112  48.323  48.533  48.734  48.915  49.061  49.156
# 233      Zimbabwe  48.178  48.179  48.148  48.079  47.977  47.852  47.724
#
#        1967    1968  ...    1999    2000    2001    2002    2003    2004  \
# 229  42.331  41.270  ...  31.504  31.113  30.462  29.612  28.631  27.563
# 230  55.310  55.530  ...  41.322  40.407  39.624  38.973  38.445  38.025
# 231  38.734  38.317  ...  24.899  24.684  24.458  24.199  23.897  23.550
# 232  49.195  49.175  ...  45.048  45.010  44.907  44.755  44.566  44.340
# 233  47.614  47.536  ...  31.268  30.876  30.577  30.361  30.215  30.123
#
#        2005    2006    2007    2008
# 229  26.464  25.391  24.391  23.508
# ...

# %%
# Histogram
plt.figure(figsize=(20, 10))
plt.hist(df, bins=10, edgecolor='pink')
plt.xticks(rotation=45)
plt.title('Histogram')
plt.xlabel('Country')
plt.ylabel('1960')
plt.show()

# %%
# Box Plot
countryrow = df[df['Country'] == 'Samoa']

value = countryrow.iloc[:, 1:].values.flatten()

plt.figure(figsize=(8, 6))
plt.boxplot(value)
plt.title('Box Plot')
plt.xlabel('Value')
plt.show()

# %%
# Bullet Chart
year = countryrow.columns[1:]

target = 20.0

d1 = plo.Bar(x=year, y=value, name='Actual', marker=dict())
d2 = plo.Scatter(x=year, y=[target] * len(year), mode='lines', name='Target', line=dict(color='black', dash='dash'))

layout = plo.Layout(
    title='Bullet Chart',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Value'))

fig = plo.Figure(data=[d1, d2], layout=layout)
fig.show()
# Out:
# <div>                            <div id="637da599-5898-477f-aebb-ef720502c4dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("637da599-5898-477f-aebb-ef720502c4dc")) {                    Plotly.newPlot(                        "637da599-5898-477f-aebb-ef720502c4dc",                        [{"name":"Actual","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008"],"y":[48.202,47.788,47.226,46.491,45.591,44.558,43.447,42.331,41.27,40.297,39.414,38.599,37.821,37.07,
# ...

# %%
# Line Chart
plt.figure(figsize=(15, 6))
plt.plot(year, value)
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Line Chart')
plt.xlabel('Year')
plt.ylabel('Value')
plt.show()
