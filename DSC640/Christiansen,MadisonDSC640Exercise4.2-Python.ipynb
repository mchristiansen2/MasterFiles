# %% [markdown]
# ### DSC640 Exercise 4.2
# ### Madison Christiansen
# ### 1 heat map, 1 spatial chart and 1 lollipop chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np


df = pd.read_csv('/Users/madisonchristiansen/Desktop/costcos-geocoded.csv')   
df.head()
# Out:
#                      Address        City    State    Zip Code   Latitude  \
# 0   1205 N. Memorial Parkway  Huntsville  Alabama  35801-5930  34.743095
# 1       3650 Galleria Circle      Hoover  Alabama  35244-2346  33.377649
# 2     8251 Eastchase Parkway  Montgomery  Alabama       36117  32.363889
# 3  5225 Commercial Boulevard      Juneau   Alaska  99801-7210  58.359200
# 4       330 West Dimond Blvd   Anchorage   Alaska  99515-1950  61.143266
#
#     Longitude
# 0  -86.600955
# 1  -86.812420
# 2  -86.150884
# 3 -134.483000
# 4 -149.884217

# %%
# Heat map
sns.heatmap(df[['Latitude', 'Longitude']])
plt.title('Heat Map of Latitude and Longitude')
plt.show()

# %%
# Spatial chart
fig = px.scatter_mapbox(df, lat="Latitude", lon="Longitude", hover_name="Address",
                        hover_data=["City", "State", "Zip Code"])
fig.update_layout(mapbox_style="open-street-map") ## map of the world, able to zoom in and out
fig.show()
# Out:
# <div>                            <div id="3bfc0cd9-3782-4726-8d02-985b20781a5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bfc0cd9-3782-4726-8d02-985b20781a5d")) {                    Plotly.newPlot(                        "3bfc0cd9-3782-4726-8d02-985b20781a5d",                        [{"customdata":[["Huntsville","Alabama","35801-5930"],["Hoover","Alabama","35244-2346"],["Montgomery","Alabama","36117"],["Juneau","Alaska","99801-7210"],["Anchorage","Alaska","99515-1950"],["Anchorage","Alaska","99508-3115"],["Prescott","Arizona","86301-6717"],["Tucson","Arizona","85741-2864"],["Tucson","Arizona","85712-5834"],["Glendale","Arizona","85308-8711"],["Gilbert","Arizona","85296-6303"],["Tempe","Arizona","85284-1103"],["Scottsdale","Arizona","85260-250
# ...

# %%
# Lollipop chart
fig, ax = plt.subplots(figsize=(20, 10))
ax.stem(df['State'])
ax.set_xticks(y)
ax.set_xticklabels(df['City'], rotation=90)
ax.set_ylabel('State')
ax.set_title('Lollipop Chart of State')
plt.tight_layout()
plt.show()
