# %% [markdown]
# ### DSC550 6.2 Milestone 1: Data Selection and EDA
# ### Madison Christiansen

# %% [markdown]
# #### A common business problem that is seen throughout many companies is predicting churn rates in a subscription-based business. The churn rate refers to the rate at which the customers cancel their subscriptions. When a customer cancels their subscription, the business is impacted by losing revenue from the customer and the potential revenue from the future subscriptions. High churn rates can lead to negative publicity for the business and further hurt the business future with new potential customers. Using a predictive model to anticipate why customers are likely to cancel their subscriptions can give the business a better idea on how to market and keep customers. By analyzing customer data such as demographics, subscription type, and more can help give a better understand as to if the customer is at high risk of leaving.
# #### Having access to accurate and relevant data is needed build an effective model. The Telco Customer Churn data contains information about a fictional telco company that provides home phone and internet services to around 7,000 customers in California. This data set includes information of the customers who left, different services the customer has signed up for, account information, and customer demographics.
# #### The target of my model is understanding how the churn is impacted. With the many other columns of data, the possibilities are wide. For example, looking at the demographics of the customers to understand what type of people are canceling their subscriptions. Or another way to look at it the services they have and if there is a component that shows why some are canceling their subscriptions.
# #### By leveraging customer data and expertise in data analysis and modeling, businesses can develop a model that accurately predicts when a customer is at risk of leaving and takes proactive measures to retain them. This can help businesses improve customer retention, reduce churn rates, and increase revenue and profitability.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

## importing the dataset
churndf = pd.read_csv('/Users/madisonchristiansen/Desktop/bigml_59c28831336c6604c800002a.csv')   
churndf.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
## column names 
list(churndf.columns.values)
# Out:
# ['state',
#  'account length',
#  'area code',
#  'phone number',
#  'international plan',
#  'voice mail plan',
#  'number vmail messages',
#  'total day minutes',
#  'total day calls',
#  'total day charge',
#  'total eve minutes',
#  'total eve calls',
#  'total eve charge',
#  'total night minutes',
#  'total night calls',
#  'total night charge',
#  'total intl minutes',
#  'total intl calls',
#  'total intl charge',
#  'customer service calls',
#  'churn']

# %%
# undersding the churn overall with pie chart
churndf["churn"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='churn'>

# %% [markdown]
# ##### With this pie chart you can see the overall amount of customers that churn is less then thoes who stay with the company

# %%
## general histograms for all columns 
for x in churndf.columns[1:19]:
    plt.hist(churndf[x])
    plt.title("Plot of "+ x)
    plt.show()

# %%
# boxplot of churn and total day calls in minutes
churndf.boxplot(column='total day minutes',by='churn', figsize=(10,5))
plt.ylabel("Total Day Minutes")
plt.xlabel("Churn")
plt.xticks()
plt.show()

# %% [markdown]
# ##### This graph show us the churn based on the total minutes in a day someone calls . You can see that there is not a huge difference between the churn rates for the amount of minutes throughout the day.

# %%
# boxplot of churn and total charge a day
churndf.boxplot(column='total day charge',by='churn', figsize=(10,5))
plt.ylabel("Total Day Charge")
plt.xlabel("Churn")
plt.xticks()
plt.show()

# %% [markdown]
# ##### The daily charges is the amount the customer is charged daily. You can see that the churn is ture or fala, the higher the monthly charges the more likley the customer is to churn (cancel the subscription).

# %%
# boxplot of churn and customer sercice calls 
churndf.boxplot(column='customer service calls',by='churn', figsize=(10,5))
plt.ylabel("Customer Service Calls")
plt.xlabel("Churn")
plt.xticks()
plt.show()

# %% [markdown]
# ##### Looking at the amount of customer service calls you can see that they do not differ greatly, but the higher amount of calls is associated with higher rates of churn.

# %%
crosstb = pd.crosstab(churndf.state, churndf.churn)
# Creating barplot of state and churn
pl = crosstb.plot(kind="bar", width=0.7, figsize=(10,10), xlabel='State', ylabel="Churn Number")

# %% [markdown]
# ##### With this bar graph you can see by state how the churn numbers are recorded. MD, NJ, and TX have the hightest churns.

# %% [markdown]
# #### From my graphical analysis you can gather a basic understand of the churn data and how it is compared to different aspects of customers subscirptions. The pie chart shows us the churn numbers for this company are more false then true, meaning most customers are continuing the subscirption. The histograms show a good overview of all the column variables. Pointing out the plot of acount lengths you can see the lengths of accounts are on average between 50 and 150. The three boxplost can show us the churn numbers based on the total minutes in a day someone uses the phone, the total charge in a day, and the total number of customer service calls. The customer service calls are significant, because usually if someone is calling customer service it means they are having issues with the services. You can see the more calls made to customer service lines up with more churn. The bar graph is a great overview of the churn and non churn by each state. You can see that the higher churn is from MD, NJ, and TX. The lower churn is from WV, AL, and VA. It would be benifical to take this graph a step further and look at the differences in numbers of the churn and non churn of each state.
# #### This analysis gives a good starting point to build off of and will allow for a better understand of why people are not continuing their subscriptions.

# %% [markdown]
# ### DSC550 8.2 Milestone 2: Data Preperation

# %%
churndf
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
## checking dataset for missing values 
churndf.isnull().sum().sort_values(ascending=False)
# Out:
# state                     0
# total eve calls           0
# customer service calls    0
# total intl charge         0
# total intl calls          0
# total intl minutes        0
# total night charge        0
# total night calls         0
# total night minutes       0
# total eve charge          0
# total eve minutes         0
# account length            0
# total day charge          0
# total day calls           0
# total day minutes         0
# number vmail messages     0
# voice mail plan           0
# international plan        0
# phone number              0
# area code                 0
# churn                     0
# dtype: int64

# %% [markdown]
# #### No missing data was found.

# %%
## creating new columns for total calls, minutes, and charge through the day 
churndf['total calls in the day'] = churndf['total day calls'] + churndf['total eve calls'] + churndf['total night calls'] # calls
churndf['total minutes in the day'] = churndf['total day minutes'] + churndf['total eve minutes'] + churndf['total night minutes'] # minutes
churndf['total charge in the day'] = churndf['total day charge'] + churndf['total eve charge'] + churndf['total night charge'] # charge
churndf 
# giving the total for the entire day - an easy look over
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# #### Creating the new columns to show the total charge, minutes, and calls throughout one whole day. Including the day, eve, and night.

# %%
## creating dummy variables for columns to be included in future analysis 
pd.get_dummies(churndf, columns=['voice mail plan', 'international plan'])
# Out:
#      state  account length  area code phone number  number vmail messages  \
# 0       KS             128        415     382-4657                     25
# 1       OH             107        415     371-7191                     26
# 2       NJ             137        415     358-1921                      0
# 3       OH              84        408     375-9999                      0
# 4       OK              75        415     330-6626                      0
# ...    ...             ...        ...          ...                    ...
# 3328    AZ             192        415     414-4276                     36
# 3329    WV              68        415     370-3271                      0
# 3330    RI              28        510     328-8230                      0
# 3331    CT             184        510     364-6381                      0
# 3332    TN              74        415     400-4344                     25
#
#       total day minutes  total day calls  total day charge  total eve minutes  \
# ...

# %% [markdown]
# #### Creating dummy variables for two columns that had a yes and no response. For future analysis use.

# %%
## grouping columns to see by state what the churn data looks like
churnbystate = churndf.groupby(['state', 'churn']).mean()
churnbystate
# Out:
#              account length   area code  number vmail messages  \
# state churn
# AK    False       94.693878  440.142857               9.612245
#       True       138.000000  415.000000               0.000000
# AL    False       98.125000  431.430556               7.569444
#       True        97.125000  423.375000               3.625000
# AR    False       94.840909  443.318182               8.340909
# ...                     ...         ...                    ...
# WI    True       112.000000  454.714286               4.000000
# WV    False       95.145833  441.322917               8.864583
#       True        98.200000  471.300000               7.400000
# WY    False      104.985294  434.205882               7.000000
#       True       111.444444  457.222222               2.888889
#
#              total day minutes  total day calls  total day charge  \
# state churn
# AK    False         179.516327        95.591837         30.518163
# ...

# %% [markdown]
# #### Looking at the average data by grouping by state and churn. Seeing if there is a significant difference and what to futher analyze.

# %% [markdown]
# ### Milestone 3

# %%
## dropping the state and phone number columns 
# churndf2 = churndf2.drop(columns=['phone number'])  - not needed
# churndf2 = churndf2.drop(columns=['state']) - not needed when the area code is provided 
churndf2.head()
# Out:
#    account length  area code  international plan  voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  ...  \
# 0             45.07              197.4               99  ...
# 1             27.47              195.5              103  ...
# ...

# %%
## STEP 1 Changing the churn column to an int in order for it to be evaluated in the model 
## YES - 1, NO - 0
churndf2['churn'] = churndf2['churn'].astype(int)
churndf2.head()
# Out:
#    account length  area code  international plan  voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  ...  \
# 0             45.07              197.4               99  ...
# 1             27.47              195.5              103  ...
# ...

# %%
## STEP 2 - Changing the yes and no columns to int as well
churndf2['international plan'] = churndf2['international plan'].replace(to_replace=["yes","no"], value=[1,0]) # (Y=1 and N=0)
churndf2['voice mail plan'] = churndf2['voice mail plan'].replace(to_replace=["yes","no"], value=[1,0]) # (Y=1 and N=0)
churndf2.head()
# Out:
#    account length  area code  international plan  voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  ...  \
# 0             45.07              197.4               99  ...
# 1             27.47              195.5              103  ...
# ...

# %% [markdown]
# ### Using a Random Forest classifer model for the churn data. This type of model can capture the relationships and interactions between the various features in the dataset. Along with this it provides a measure of feature importance to identify the key factors contributing to churn. The metrics such as accuracy, percision, recall, and the F1 score will give a good understanding as to if the model is good for the data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


X = churndf2.drop('churn', axis=1) ## STEP 3 - choosing the churn as the target column 
y = churndf2['churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) ## STEP 4 - training the data and setting the test size 

rf_classifier = RandomForestClassifier(n_estimators=100)

# %%
## STEP 5 - train the classifier
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
## STEP 6 - predict on the test set
y_pred = rf_classifier.predict(X_test)

## STEP 7 - accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.967016491754123

# %%
# STEP 8 - precision
precision = precision_score(y_test, y_pred)
print(f"Precision: {precision}")

# STEP 9 - recall
recall = recall_score(y_test, y_pred)
print(f"Recall: {recall}")

# STEP 10 - F1 score
f1 = f1_score(y_test, y_pred)
print(f"F1 score: {f1}")
# Out:
# Precision: 0.08108108108108109
# Recall: 0.07058823529411765
# F1 score: 0.07547169811320756

# %% [markdown]
# ### The accuracy shows 96% which means that the Random Forest classifier correctly predicted the churn label for 96% of the instancess in the test set. The precision of 8% shows that out of the predictive positive only 8% were actual true positives. This is an indication that the models ability to correctly identify postivie instances is low. The recall and F1 score both tell this as well that the models preformace in precision and recall is poor.

# %% [markdown]
# ### Using a logistic regression model is efficent when looking at larger data sets. This type of model can interperte coefficients that can help understadn the impact of the different features on the churn likelihood. This model can be a good base line model that is simple and allow for a greater understanding.

# %%
## Trying a logistic regression model to check outcome and see if better
from sklearn.linear_model import LogisticRegression

logreg_model = LogisticRegression() 

logreg_model.fit(X_train, y_train)  # fitting the data

y_pred2 = logreg_model.predict(X_test) # predict 

# metrics
accuracy = accuracy_score(y_test, y_pred2)
precision = precision_score(y_test, y_pred2)
recall = recall_score(y_test, y_pred2)
f1 = f1_score(y_test, y_pred2)
# Out:
# /Users/madisonchristiansen/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(f"Accuracy: {accuracy}") 
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 score: {f1}")
# Out:
# Accuracy: 0.8800599700149925
# Precision: 0.7777777777777778
# Recall: 0.08235294117647059
# F1 score: 0.14893617021276592

# %% [markdown]
# ### With the accuracy being at 88% this is a good indication of the models ability to correctly predict the churn for 88% of the instances in the test set. The precision being 77% implies that the model has the ability to avoid the false postives. The Recall of 82% meanms that the model identified the positive churn results. Although the F1 scroe is still low the Logistic Regression model preformed better. For this data set the Logistic Regression model is a better fit.
